# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from time import sleep

# %%
msg = ''' 
Hello,
Greetings from Venuefy,
Hope you and your family are safe and healthy.
    Here is an opportunity you don't want to miss. 
Venuefy is a Bengal Based Venue and Non Venue Providing Company. We also deal in organising events via WDI EVENTS.
As Venuefy was born in midst of corona pandemic, under the 'Aatmnirbhar Bharat' revolution, we want to help other MSME Companies. As such we have launched a platform for business related people to serve their needs.

Please Join the whatsapp platform for updates.
https://chat.whatsapp.com/EFsOQLXWi9z1W2ByBEucIe

*For Entrepreneurs*
For entrepreneurs, this group will really be beneficial for promotional purposes. 
As for now promotion charges are completely ```FREE```.
If you want to send something in group, send it to one of the Admins.

*For Lead Agents*
For Lead Agents, This group will be very beneficial for forwarding leads. 
Venuefy commission model is mentioned below, contact us for more details. 
If the Lead belongs to other 3rd party, the commission model is as the said 3rd party decides.

*Venuefy Commission Model*
We also have a commission model for those who bring business to us in event industry.
Description of the commission model provided:
Upto 1 lakhs- Rs. 1500
More than 1 lakhs and less than or equal to 5 lakhs- Rs 3000
More than 5 lakhs and less than or equal to 10 lakhs- Rs 6000
More than 10 lakhs and less than or equal to 15 lakhs- Rs 7500
More than 15 lakhs and less than or equal to 20 lakhs- Rs 10000
More than 20 lakhs and less than or equal to 25 lakhs- Rs 15000
More than 25 lakhs and less than or equal to 30 lakhs- Rs 20000
More than 30 lakhs- Rs 25000

The good performers will also be provided with Gift Cards and some extra benefits.
Please feel free to contact for more detail.

*Rules of engagement*
\u2022 This service is free for now.
\u2022 Please Respect other participants.
\u2022 Please Like, Share and engage in promotional activities in group
\u2022 Please tell your lead to mention your name,contact for referrance in commission part
\u2022 Admins reserve the rights to remove anyone from the group.
\u2022 If you want to send something in group, Send it to one of the admins with your contact details.
\u2022 If you want to Report a problem or someone, Please send the screenshot with reason to one of the Admins.
\u2022 Veneufy reserves the right to it's intellectual property as under the copyright Act.
\u2022 By joining the group you accept the rules of engagement.

```We believe in "Sabke Sath Sabka Vikas"```

With Regards,
Venuefy Services Private Limited
Kolkata
'''
msg = msg.split("\n")

# %%
# message
def message():
    for i in msg:
        yield i

# %%
for i in message():
    print(i)
# Out:
#
# Hello,
# Greetings from Venuefy,
# Hope you and your family are safe and healthy.
#     Here is an opportunity you don't want to miss.
# Venuefy is a Bengal Based Venue and Non Venue Providing Company. We also deal in organising events via WDI EVENTS.
# As Venuefy was born in midst of corona pandemic, under the 'Aatmnirbhar Bharat' revolution, we want to help other MSME Companies. As such we have launched a platform for business related people to serve their needs.
#
# Please Join the whatsapp platform for updates.
# https://chat.whatsapp.com/EFsOQLXWi9z1W2ByBEucIe
#
# *For Entrepreneurs*
# For entrepreneurs, this group will really be beneficial for promotional purposes.
# As for now promotion charges are completely ```FREE```.
# If you want to send something in group, send it to one of the Admins.
#
# *For Lead Agents*
# For Lead Agents, This group will be very beneficial for forwarding leads.
# Venuefy commission model is mentioned below, contact us for more details.
# ...

# %%
#list of names

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome('./chromedriver')
driver.get("https://web.whatsapp.com/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...

# %%
def fun(name):
    user = driver.find_element_by_class_name("_3e4VU")
    user.click()
    sleep(10)
    input_box = driver.find_element_by_xpath('//div[@class="_3FRCZ copyable-text selectable-text"]')
    input_box.send_keys(name)
    sleep(10)
    contact = driver.find_element_by_xpath('//span[@title="%s"]'%name)
    contact.click()
    sleep(10)
    message_box = driver.find_element_by_xpath('//div[@class="_3uMse"]')
    message_box.send_keys(message)
    sleep(10)
    send_button = driver.find_element_by_xpath('//button[@class="_1U1xa"]')
    send_button.click()
    sleep(10)

# %%
for name in names:
    fun(name)

# %%
message_box = driver.find_element_by_xpath('//div[@class="_3uMse"]')
ac = ActionChains(driver)
# message_box.send_keys(message)
# message_box.key_down(keys.SHIFT).send_keys("")
# send_button = driver.find_element_by_xpath('//button[@class="_1U1xa"]')
# send_button.click()

# %%
newline = ac.key_down(Keys.SHIFT).send_keys(Keys.RETURN).key_up(Keys.SHIFT)

# %%
message_box.send_keys(" message")
newline.perform()
message_box.send_keys("lol")

# %%
# --- functions ---
import tkinter as tk
def on_open():
    global driver

    if not driver:
        driver = selenium.webdriver.Firefox()
        url = e.get()
        driver.get(url)

def on_close():
    global driver

    if driver:
        driver.close()
        driver = None

# --- main ---

driver = None

root  = tk.Tk()

e = tk.Entry(root)
e.pack()
e.insert('end', 'https://stackoverflow.com')

b = tk.Button(root, text='Selenium Open', command=on_open)
b.pack()

b = tk.Button(root, text='Selenium Close', command=on_close)
b.pack()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Jaba\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-11-f3867b80d950>", line 7, in on_open
#     driver = selenium.webdriver.Firefox()
# NameError: name 'selenium' is not defined

# %%
from tkinter import *


# Here, we are creating our class, Window, and inheriting from the Frame
# class. Frame is a class from the tkinter module. (see Lib/tkinter/__init__)
class Window(Frame):

    # Define settings upon initialization. Here you can specify
    def __init__(self, master=None):
        
        # parameters that you want to send through the Frame class. 
        Frame.__init__(self, master)   

        #reference to the master widget, which is the tk window                 
        self.master = master

        #with that, we want to then run init_window, which doesn't yet exist
        self.init_window()

    #Creation of init_window
    def init_window(self):

        # changing the title of our master widget      
        self.master.title("GUI")

        # allowing the widget to take the full space of the root window
        self.pack(fill=BOTH, expand=1)

        # creating a button instance
        quitButton = Button(self, text="Exit",command=self.client_exit)

        # placing the button on my window
        quitButton.place(x=0, y=0)

       

    def client_exit(self):
        exit()

# root window created. Here, that would be the only window, but
# you can later have windows within windows.
root = Tk()

root.geometry("400x300")

#creation of an instance
app = Window(root)

#mainloop 
root.mainloop()

# %%
from tkinter import *

class Window(Frame):


    def __init__(self, master=None):
        Frame.__init__(self, master)                 
        self.master = master
        self.init_window()
    


    #Creation of init_window
    def init_window(self):

        # changing the title of our master widget      
        self.master.title("GUI")

        # allowing the widget to take the full space of the root window
        self.pack(fill=BOTH, expand=1)

        # creating a button instance
        quitButton = Button(self, text="Quit", command = root.destroy)

        # placing the button on my window
        quitButton.place(x=0, y=0)

root = Tk()

#size of the window
root.geometry("400x300")
root.lift()
root.attributes('-topmost',True)
root.after_idle(root.attributes,'-topmost',False)
app = Window(root)
root.mainloop()

# %%
import tkinter as tk

def countdown(count):
    # change text in label        
    label['text'] = count

    if count > 0:
        # call countdown again after 1000ms (1s)
        root.after(1000, countdown, count-1)

root = tk.Tk()

label = tk.Label(root)
label.place(x=35, y=15)

# call countdown first time    
countdown(5)
# root.after(0, countdown, 5)

root.mainloop()
